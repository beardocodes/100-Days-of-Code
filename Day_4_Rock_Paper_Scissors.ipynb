# %% [markdown]
# <a href="https://colab.research.google.com/github/beardocodes/100-Days-of-Code/blob/main/Day_4_Rock_Paper_Scissors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Day 4 : Rock Paper Scissors

import random

rock = """
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
"""

paper = """
     _______
---'    ____)____
           ______)
          _______)
         _______)
---.__________)
"""

scissors = """
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
"""

# Capturing Choices

# The program needs two players: you and the computer.

# User Choice: takes your typed number and converts it from a string to an integer.

# Computer Choice: generates a random whole number between 0 and 2 (inclusive).



user_choice = int(input("What do you choose/ Type 0 for Rock, 1 for Paper, or 2 for Scissors.\n"))

computer_choice = random.randint(0,2)

game_images = [rock, paper, scissors]


# Phase A: Validation
# Before doing anything else, the code checks if you typed a weird number (like 7 or -1).
# If you did, the game ends immediately to prevent errors later when trying to find an image at an index that doesn't exist.



if user_choice < 0 or user_choice >=3:
  print("You entered an invalid choice. You lose")


# Phase B: Printing the Battle
# If the input is valid, it uses the index to print the ASCII art for both players:


else:
  print(game_images[user_choice])
  print(f"Computer chose:\n")
  print(game_images[computer_choice])


# Phase C: Determining the Winner
# The code uses if/elif statements to check for three scenarios:


  if user_choice == 0 and computer_choice ==2:
    print("You win!")
  elif computer_choice == 0 and user_choice ==2:
    print("You lose")
  elif user_choice > computer_choice:
    print("You win!")
  elif computer_choice > user_choice:
    print("You lose")
  elif user_choice == computer_choice:
    print("It's a draw")
  else:
    print("You entered an invalid choice. You lose")


# 1. The "Exceptions to the Rule" (Rock vs. Scissors)

# Normally, a higher number beats a lower number. But in this game, Rock (0) beats Scissors (2).
# Because this breaks the "higher number wins" math rule, the code has to check for
# this specific matchup first.

# 2. The General Rule (Higher Number Wins)

# Once the Rock vs. Scissors exception is out of the way, the math works perfectly for the rest of the game:
# Paper (1) is greater than Rock (0), then Paper wins!
# Scissors (2) is greater than Paper (1), then Scissors wins!
# So, whoever has the strictly higher number wins the round.

# 3. The Draw

# If both the user and the computer picked
# the exact same number, it’s a tie.
# Out:
# What do you choose/ Type 0 for Rock, 1 for Paper, or 2 for Scissors.
# 2
#
#     _______
# ---'   ____)____
#           ______)
#        __________)
#       (____)
# ---.__(___)
#
# Computer chose:
#
#
#      _______
# ---'    ____)____
#            ______)
#           _______)
#          _______)
# ---.__________)
#
# You win!
